# %%
# !./terraform init
# Out:
# Initializing the backend...
#
# Initializing provider plugins...
# - Reusing previous version of hashicorp/random from the dependency lock file
# - Reusing previous version of hashicorp/google from the dependency lock file
# - Using previously-installed hashicorp/random v3.4.3
# - Using previously-installed hashicorp/google v4.34.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
# !./terraform plan -var="project_id=steveswalker-sandbox" -var="region=us-central1" -var="zone=us-east1"
# Out:
# random_id.id: Refreshing state... [id=jOKD4g]
# data.google_project.steveswalker-sandbox: Reading...
# google_notebooks_instance.basic_instance: Refreshing state... [id=projects/steveswalker-sandbox/locations/us-east1-b/instances/edw-notbook-8ce283e2]
# google_bigquery_dataset.ds_edw: Refreshing state... [id=projects/steveswalker-sandbox/datasets/ds_edw]
# google_cloudfunctions2_function.function: Refreshing state... [id=projects/steveswalker-sandbox/locations/us-central1/functions/gcs-load-bq]
# data.google_project.steveswalker-sandbox: Read complete after 0s [id=projects/steveswalker-sandbox]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # google_bigquery_table.tbl_edw_taxi will be created
#   + resource "google_bigquery_table" "tbl_edw_taxi" {
#       + creation_time       = (known after apply)
# ...

# %%
# !./terraform apply  -var="project_id=steveswalker-sandbox" -var="region=us-central1" -var="zone=us-east1"  -auto-approve

# %%
# !./terraform apply -destroy -var="project_id=steveswalker-sandbox" -var="region=us-central1" -var="zone=us-east1"  -auto-approve
# Out:
# random_id.id: Refreshing state... [id=jOKD4g]
# data.google_project.steveswalker-sandbox: Reading...
# google_notebooks_instance.basic_instance: Refreshing state... [id=projects/steveswalker-sandbox/locations/us-east1-b/instances/edw-notbook-8ce283e2]
# google_cloudfunctions2_function.function: Refreshing state... [id=projects/steveswalker-sandbox/locations/us-central1/functions/gcs-load-bq]
# google_bigquery_dataset.ds_edw: Refreshing state... [id=projects/steveswalker-sandbox/datasets/ds_edw]
# data.google_project.steveswalker-sandbox: Read complete after 1s [id=projects/steveswalker-sandbox]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # google_bigquery_dataset.ds_edw will be destroyed
#   - resource "google_bigquery_dataset" "ds_edw" {
#       - creation_time                   = 1675528688436 -> null
# ...
