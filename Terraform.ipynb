# %%
# !./terraform init
# Out:
# Initializing the backend...
#
# Initializing provider plugins...
# - Reusing previous version of hashicorp/google from the dependency lock file
# - Using previously-installed hashicorp/google v4.34.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %%
# !./terraform plan -var="project_id=g-sql-morphic-luminous" -var="region=us-central1" -var="zone=us-east1"
# Out:
# google_bigquery_dataset.ds_edw: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw]
# google_notebooks_instance.basic_instance: Refreshing state... [id=projects/g-sql-morphic-luminous/locations/us-east1-b/instances/edw-notebook-intro-v111]
# data.google_project.g-sql-morphic-luminous: Reading...
# google_bigquery_table.tbl_edw_taxi2: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw/tables/tbl_edw_taxi2]
# google_bigquery_table.tbl_edw_taxi: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw/tables/tbl_edw_taxi]
# data.google_project.g-sql-morphic-luminous: Read complete after 0s [id=projects/g-sql-morphic-luminous]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # google_cloudfunctions2_function.function will be created
# ...

# %%
# !./terraform apply -var="project_id=g-sql-morphic-luminous" -var="region=us-central1" -var="zone=us-east1" -auto-approve
# Out:
# data.google_project.g-sql-morphic-luminous: Reading...
# google_notebooks_instance.basic_instance: Refreshing state... [id=projects/g-sql-morphic-luminous/locations/us-east1-b/instances/edw-notebook-intro-v111]
# google_bigquery_dataset.ds_edw: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw]
# data.google_project.g-sql-morphic-luminous: Read complete after 0s [id=projects/g-sql-morphic-luminous]
# google_bigquery_table.tbl_edw_taxi: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw/tables/tbl_edw_taxi]
# google_bigquery_table.tbl_edw_taxi2: Refreshing state... [id=projects/g-sql-morphic-luminous/datasets/ds_edw/tables/tbl_edw_taxi2]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#
# Terraform will perform the following actions:
#
#   # google_cloudfunctions2_function.function will be created
# ...
